# %% [markdown]
# Importing relevant packages

# %%
import pandas as pd
import locale
import plotly.express as px

# %% [markdown]
# Importing the database

# %%
data = pd.read_csv('listings.csv', low_memory = False)

# %% [markdown]
# First, let's develop a function to turn variables with prices into numeric values

# %%
def money_to_numeric(array, locale):
    """
    This function convert money style array to numeric array
    
    Input:
    array         - An array with money format
    locale        - Locale package
    
    Output:
    numeric_array - An array with data types already converted 
    """
    
    numeric_array = [locale.atof(str(element).strip("$")) for element in array]
    
    return numeric_array

# %% [markdown]
# and apply it to price related columns

# %%
locale.setlocale(locale.LC_ALL, 'es_MX.UTF8')
array = ['price','weekly_price','monthly_price','security_deposit','cleaning_fee','extra_people']
data[array] = data[array].apply(lambda col: money_to_numeric(col, locale))

# %% [markdown]
# The questions proposed in this notebook are:
# 1. Which neighbourhood is the more expensive?
# 2. Which neighbourhood has more super hosts?
# 3. Is there a relantionship between super hosts and price in the neighbourhoods?
# 4. Why are these neighbourhoods expensive?

# %% [markdown]
# ### Which neighbourhoods are more expensive?

# %%
top_5_neighbourhoods = data.groupby('neighbourhood_cleansed')                       # Grouping data by neighbourhood
top_5_neighbourhoods = top_5_neighbourhoods.agg({'price': 'mean'})                  # Calculating average price
top_5_neighbourhoods = top_5_neighbourhoods.sort_values('price', ascending = False) # Sorting from largest to smallest
top_5_neighbourhoods = top_5_neighbourhoods.head(5)
top_5_neighbourhoods
# Out:
#                               price
# neighbourhood_cleansed
# Cuajimalpa de Morelos   3131.604288
# Iztapalapa              2689.812102
# Xochimilco              2441.907801
# Miguel Hidalgo          2021.496550
# Cuauhtémoc              1655.697666

# %% [markdown]
# Is easy to see that on average, Cuajimalpa de Morelos is the most expensive, followed by Iztapalapa and Xochimilco. But the catch here is that, they are the most expensive on average, that can be because of the pressence of outliers.
#
# To take into account that is a good idea to look at a Box plot.
#
# Note that the graph lacks of data points with prices above $10,000 for visualization purposes

# %%
# First, get the rows from the 5 neighbourhoods
filtered_neighbourhoods = top_5_neighbourhoods.index
# Filter data to only take info from the neighbourhoods and prices below $10,000
filtered_data = data.loc[(data.neighbourhood_cleansed.isin(filter_neighbourhoods)) & (data.price <=10000)]
# Box plot
fig1 = px.box(filtered_data, 'neighbourhood_cleansed', 'price', points = 'all')
fig1.show()
# Out:
# <div>
#
#
#             <div id="cf6fee38-379b-4524-a535-2b9d86465050" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cf6fee38-379b-4524-a535-2b9d86465050")) {
#                     Plotly.newPlot(
#                         'cf6fee38-379b-4524-a535-2b9d86465050',
#                         [{"alignmentgroup": "True", "boxpoints": "all", "hovertemplate": "neighbourhood_cleansed=%{x}<br>price=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x": ["Cuajimalpa de Morelos", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Miguel Hidalgo", "Miguel Hidalgo", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Miguel Hidalgo", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Miguel Hidalgo", "Cuauht\u00e9moc", "Miguel Hidalgo", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Miguel Hidalgo", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Miguel Hidalgo", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Miguel Hidalgo", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Miguel Hidalgo", "Miguel Hidalgo", "Miguel Hidalgo", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Miguel Hidalgo", "Miguel Hidalgo", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Miguel Hidalgo", "Cuauht\u00e9moc", "Miguel Hidalgo", "Miguel Hidalgo", "Miguel Hidalgo", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Miguel Hidalgo", "Miguel Hidalgo", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuajimalpa de Morelos", "Cuauht\u00e9moc", "Cuajimalpa de Morelos", "Cuauht\u00e9moc", "Cuajimalpa de Morelos", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Miguel Hidalgo", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Miguel Hidalgo", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Miguel Hidalgo", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Iztapalapa", "Miguel Hidalgo", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Miguel Hidalgo", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Miguel Hidalgo", "Miguel Hidalgo", "Miguel Hidalgo", "Miguel Hidalgo", "Miguel Hidalgo", "Miguel Hidalgo", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Xochimilco", "Miguel Hidalgo", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Miguel Hidalgo", "Cuauht\u00e9moc", "Miguel Hidalgo", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Miguel Hidalgo", "Miguel Hidalgo", "Miguel Hidalgo", "Miguel Hidalgo", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Miguel Hidalgo", "Miguel Hidalgo", "Miguel Hidalgo", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Miguel Hidalgo", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Miguel Hidalgo", "Miguel Hidalgo", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Miguel Hidalgo", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Miguel Hidalgo", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Miguel Hidalgo", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Miguel Hidalgo", "Miguel Hidalgo", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", ...

# %% [markdown]
# The box plot shows that Cuauhtémoc and Miguel Hidalgo have more pricey properties. A Box plot with all neighbourhoods may help clarify the question

# %%
# Filter data to only take prices below $10,000
filtered_data = data.loc[data.price <=10000]
# Box plot
fig1 = px.box(filtered_data, 'neighbourhood_cleansed', 'price', points = 'all')
fig1.show()
# Out:
# <div>
#
#
#             <div id="2f73f81c-edb4-4593-a03d-031555d118a6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2f73f81c-edb4-4593-a03d-031555d118a6")) {
#                     Plotly.newPlot(
#                         '2f73f81c-edb4-4593-a03d-031555d118a6',
#                         [{"alignmentgroup": "True", "boxpoints": "all", "hovertemplate": "neighbourhood_cleansed=%{x}<br>price=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x": ["Cuajimalpa de Morelos", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Coyoac\u00e1n", "Miguel Hidalgo", "Coyoac\u00e1n", "Miguel Hidalgo", "Benito Ju\u00e1rez", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Miguel Hidalgo", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Azcapotzalco", "Miguel Hidalgo", "Cuauht\u00e9moc", "Miguel Hidalgo", "Iztacalco", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Benito Ju\u00e1rez", "Cuauht\u00e9moc", "Benito Ju\u00e1rez", "Cuauht\u00e9moc", "Miguel Hidalgo", "Cuauht\u00e9moc", "Coyoac\u00e1n", "Cuauht\u00e9moc", "Tlalpan", "Tlalpan", "Cuauht\u00e9moc", "Tlalpan", "Cuauht\u00e9moc", "Benito Ju\u00e1rez", "Coyoac\u00e1n", "Cuauht\u00e9moc", "Miguel Hidalgo", "Benito Ju\u00e1rez", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Azcapotzalco", "Benito Ju\u00e1rez", "Coyoac\u00e1n", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Miguel Hidalgo", "Cuauht\u00e9moc", "Benito Ju\u00e1rez", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "La Magdalena Contreras", "Miguel Hidalgo", "Miguel Hidalgo", "Miguel Hidalgo", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Miguel Hidalgo", "Miguel Hidalgo", "Cuauht\u00e9moc", "Venustiano Carranza", "\u00c1lvaro Obreg\u00f3n", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Gustavo A. Madero", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Miguel Hidalgo", "Cuauht\u00e9moc", "\u00c1lvaro Obreg\u00f3n", "\u00c1lvaro Obreg\u00f3n", "Miguel Hidalgo", "Miguel Hidalgo", "Miguel Hidalgo", "Venustiano Carranza", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Miguel Hidalgo", "Miguel Hidalgo", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuajimalpa de Morelos", "Coyoac\u00e1n", "Benito Ju\u00e1rez", "Cuauht\u00e9moc", "Coyoac\u00e1n", "La Magdalena Contreras", "Cuajimalpa de Morelos", "Cuauht\u00e9moc", "Cuajimalpa de Morelos", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Miguel Hidalgo", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Coyoac\u00e1n", "Cuauht\u00e9moc", "Miguel Hidalgo", "Benito Ju\u00e1rez", "Cuauht\u00e9moc", "Coyoac\u00e1n", "Cuauht\u00e9moc", "Coyoac\u00e1n", "Coyoac\u00e1n", "Coyoac\u00e1n", "Coyoac\u00e1n", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Coyoac\u00e1n", "Cuauht\u00e9moc", "Venustiano Carranza", "Cuauht\u00e9moc", "Coyoac\u00e1n", "Cuauht\u00e9moc", "\u00c1lvaro Obreg\u00f3n", "Coyoac\u00e1n", "Miguel Hidalgo", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Coyoac\u00e1n", "Tlalpan", "Coyoac\u00e1n", "Iztapalapa", "Benito Ju\u00e1rez", "Benito Ju\u00e1rez", "Benito Ju\u00e1rez", "Tlalpan", "Miguel Hidalgo", "Coyoac\u00e1n", "Cuauht\u00e9moc", "Benito Ju\u00e1rez", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Coyoac\u00e1n", "Miguel Hidalgo", "Coyoac\u00e1n", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Miguel Hidalgo", "Miguel Hidalgo", "Coyoac\u00e1n", "Benito Ju\u00e1rez", "\u00c1lvaro Obreg\u00f3n", "Miguel Hidalgo", "Benito Ju\u00e1rez", "Benito Ju\u00e1rez", "Benito Ju\u00e1rez", "Miguel Hidalgo", "Miguel Hidalgo", "Benito Ju\u00e1rez", "Miguel Hidalgo", "Cuauht\u00e9moc", "Benito Ju\u00e1rez", "Cuauht\u00e9moc", "Benito Ju\u00e1rez", "Benito Ju\u00e1rez", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Xochimilco", "Miguel Hidalgo", "Benito Ju\u00e1rez", "Cuauht\u00e9moc", "Coyoac\u00e1n", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Coyoac\u00e1n", "Benito Ju\u00e1rez ...

# %% [markdown]
# The neighbourhoods with more properties in the high price scale are Cuauhtémoc and Miguel Hidalgo, followed by Coyoacán, Benito Juárez and Álvaro Obregón

# %% [markdown]
# ### Which neighbourhoods have more super hosts?

# %%
top_by_super_hosts = data[data.host_is_superhost == 't']
top_by_super_hosts = top_by_super_hosts.groupby('neighbourhood_cleansed')    # Groupping by neighbourhood
top_by_super_hosts = top_by_super_hosts.agg({'id': 'count'})                 # Counting the number of super hosts
top_by_super_hosts = top_by_super_hosts.sort_values('id', ascending = False) # sorting values from larger to smaller
top_by_super_hosts.head(5)
# Out:
#                           id
# neighbourhood_cleansed
# Cuauhtémoc              3353
# Miguel Hidalgo          1170
# Benito Juárez           1077
# Coyoacán                 637
# Álvaro Obregón           253

# %% [markdown]
# Cuauhtémoc, Miguel Hidalgo and Benito Juárez are the neighbourhoods with more super hosts, followed by Coyoacán and Álvaro Obregón. It is interesting that the same top pricey neighbourhoods are the ones with more super hosts.

# %% [markdown]
# ### Is there a relantionship between super hosts and price in the neighbourhoods?

# %%
# Filter data to only take info from superhosts and prices below $10,000
filtered_data = data.loc[(data.host_is_superhost == 't') & (data.price <= 10000)]
# Box plot
fig = px.box(filtered_data, 'neighbourhood_cleansed', 'price', points = 'all')
fig.show()
# Out:
# <div>
#
#
#             <div id="39a27d71-721b-41f6-911b-aadcc0ff94f5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("39a27d71-721b-41f6-911b-aadcc0ff94f5")) {
#                     Plotly.newPlot(
#                         '39a27d71-721b-41f6-911b-aadcc0ff94f5',
#                         [{"alignmentgroup": "True", "boxpoints": "all", "hovertemplate": "neighbourhood_cleansed=%{x}<br>price=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x": ["Cuauht\u00e9moc", "Coyoac\u00e1n", "Miguel Hidalgo", "Benito Ju\u00e1rez", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Miguel Hidalgo", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Coyoac\u00e1n", "Cuauht\u00e9moc", "Tlalpan", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Miguel Hidalgo", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "\u00c1lvaro Obreg\u00f3n", "\u00c1lvaro Obreg\u00f3n", "Cuauht\u00e9moc", "Miguel Hidalgo", "Miguel Hidalgo", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Coyoac\u00e1n", "Cuajimalpa de Morelos", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Coyoac\u00e1n", "Cuauht\u00e9moc", "Coyoac\u00e1n", "Coyoac\u00e1n", "Coyoac\u00e1n", "Coyoac\u00e1n", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Venustiano Carranza", "Cuauht\u00e9moc", "Coyoac\u00e1n", "Coyoac\u00e1n", "Miguel Hidalgo", "Cuauht\u00e9moc", "Coyoac\u00e1n", "Benito Ju\u00e1rez", "Benito Ju\u00e1rez", "Coyoac\u00e1n", "Cuauht\u00e9moc", "Coyoac\u00e1n", "Cuauht\u00e9moc", "Coyoac\u00e1n", "Benito Ju\u00e1rez", "Benito Ju\u00e1rez", "Cuauht\u00e9moc", "Benito Ju\u00e1rez", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Miguel Hidalgo", "Benito Ju\u00e1rez", "Cuauht\u00e9moc", "Benito Ju\u00e1rez", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Benito Ju\u00e1rez", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Miguel Hidalgo", "Miguel Hidalgo", "Miguel Hidalgo", "Coyoac\u00e1n", "Coyoac\u00e1n", "Coyoac\u00e1n", "Cuauht\u00e9moc", "Miguel Hidalgo", "Benito Ju\u00e1rez", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Miguel Hidalgo", "Miguel Hidalgo", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Miguel Hidalgo", "Cuauht\u00e9moc", "Miguel Hidalgo", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Coyoac\u00e1n", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Coyoac\u00e1n", "Cuauht\u00e9moc", "Miguel Hidalgo", "Benito Ju\u00e1rez", "Cuauht\u00e9moc", "Miguel Hidalgo", "Coyoac\u00e1n", "Venustiano Carranza", "Benito Ju\u00e1rez", "Miguel Hidalgo", "Benito Ju\u00e1rez", "Miguel Hidalgo", "Cuajimalpa de Morelos", "Benito Ju\u00e1rez", "Benito Ju\u00e1rez", "Miguel Hidalgo", "Miguel Hidalgo", "Miguel Hidalgo", "Miguel Hidalgo", "Miguel Hidalgo", "Miguel Hidalgo", "Benito Ju\u00e1rez", "Miguel Hidalgo", "Benito Ju\u00e1rez", "Cuauht\u00e9moc", "Miguel Hidalgo", "Miguel Hidalgo", "Miguel Hidalgo", "Miguel Hidalgo", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "\u00c1lvaro Obreg\u00f3n", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Miguel Hidalgo", "Cuauht\u00e9moc", "Miguel Hidalgo", "Benito Ju\u00e1rez", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Coyoac\u00e1n", "Cuauht\u00e9moc", "Cuajimalpa de Morelos", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Benito Ju\u00e1rez", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Coyoac\u00e1n", "Miguel Hidalgo", "\u00c1lvaro Obreg\u00f3n", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Coyoac\u00e1n", "Miguel Hidalgo", "Cuauht\u00e9moc", "Miguel Hidalgo", "Cuauht\u00e9moc", "Miguel Hidalgo", "Miguel Hidalgo", "Miguel Hidalgo", "Cuauht\u00e9moc", "Miguel Hidalgo", "Miguel Hidalgo", "Benito Ju\u00e1rez", "Tlalpan", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Coyoac\u00e1n", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Cuauht\u00e9moc", "Miguel Hidalgo", "Miguel Hidalgo", "Migue ...

# %% [markdown]
# The Box plot makes easy to see that Cuauhtémoc and Miguel Hidalgo has the most pricey properties with super hosts, followed by Coyoacán

# %% [markdown]
# ### Why are these neighbourhoods expensive?

# %% [markdown]
# Cuauhtémoc is basically at the turistic center of Mexico city, with attractions such as Palacio de Bellas Artes, Museo del Templo Mayor, Catedral Metropolitana and close to many more
#
# Miguel Hidalgo is next to Cuauhtémoc and some parts of Bosque de Chapultepec and Polanco are close
#
# Coyoacán is not close to the other two, but has various attractions at walking distance
#
# The three neighbourhoods are among the most valued neighbourhoods in the city, that and as mentioned before, their closeness to turistic attarctions explains the prices of their properties
